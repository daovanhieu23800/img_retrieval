# %%
from minio import Minio
import os

# Initialize MinIO client
client = Minio(
    "127.0.0.1:9000",  # Example: "localhost:9000"
    access_key="minioaccesskey",
    secret_key="miniosecretkey",
    secure=False  # Set to True if using https
)

# %%
def upload_images_to_minio(local_folder, bucket_name):
    # Check if the bucket exists, create it if it does not
    if not client.bucket_exists(bucket_name):
        client.make_bucket(bucket_name)
        print(f"Bucket '{bucket_name}' created.")

    # Loop through the files in the local folder
    for filename in os.listdir(local_folder):
        local_file = os.path.join(local_folder, filename)

        # Skip directories
        if os.path.isdir(local_file):
            continue

        # Only upload image files (optional: modify this to filter specific types)
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
            try:
                # Upload the file to MinIO
                with open(local_file, "rb") as file_data:
                    client.put_object(bucket_name, filename, file_data, os.stat(local_file).st_size)
                print(f"Uploaded {filename} to {bucket_name}")
            except Exception as e:
                print(f"Failed to upload {filename}: {e}")

# %%
local_root_folder = "./miniImageNet"
bucket_name = "image"
for root, _, files in os.walk(local_root_folder):
    print(root)
    # for file_name in files:
    #     if file_name.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp', '.tiff')):
    #         # Construct the local file path
    #         local_file_path = os.path.join(root, file_name)

    #         # Preserve the relative folder structure in the bucket
    #         relative_path = os.path.relpath(local_file_path, local_root_folder)
    #         bucket_file_path = relative_path.replace("\\", "/")  # Ensure consistent path separators

    #         # Call the upload function for each file
    upload_images_to_minio(root, bucket_name)
# Out:
# ./miniImageNet
# ./miniImageNet\n01532829
# Uploaded n01532829_10006.JPEG to image
# Uploaded n01532829_10032.JPEG to image
# Uploaded n01532829_10104.JPEG to image
# Uploaded n01532829_10127.JPEG to image
# Uploaded n01532829_1017.JPEG to image
# Uploaded n01532829_1021.JPEG to image
# Uploaded n01532829_1023.JPEG to image
# Uploaded n01532829_10259.JPEG to image
# Uploaded n01532829_10275.JPEG to image
# Uploaded n01532829_1030.JPEG to image
# Uploaded n01532829_1033.JPEG to image
# Uploaded n01532829_10400.JPEG to image
# Uploaded n01532829_1051.JPEG to image
# Uploaded n01532829_10530.JPEG to image
# Uploaded n01532829_10776.JPEG to image
# Uploaded n01532829_10861.JPEG to image
# Uploaded n01532829_10890.JPEG to image
# Uploaded n01532829_1097.JPEG to image
# Uploaded n01532829_110.JPEG to image
# Uploaded n01532829_1106.JPEG to image
# Uploaded n01532829_1114.JPEG to image
# Uploaded n01532829_11167.JPEG to image
# Uploaded n01532829_11202.JPEG to image
# Uploaded n01532829_1124.JPEG to image
# Uploaded n01532829_11266.JPEG to image
# Uploaded n01532829_11352.JPEG to image
# Uploaded n01532829_114.JPEG to image
# Uploaded n01532829_11451.JPEG to image
# Uploaded n01532829_11568.JPEG to image
# Uploaded n01532829_11626.JPEG to image
# Uploaded n01532829_11644.JPEG to image
# Uploaded n01532829_11682.JPEG to image
# Uploaded n01532829_1176.JPEG to image
# Uploaded n01532829_1179.JPEG to image
# Uploaded n01532829_11827.JPEG to image
# Uploaded n01532829_11908.JPEG to image
# Uploaded n01532829_11964.JPEG to image
# Uploaded n01532829_120.JPEG to image
# Uploaded n01532829_1210.JPEG to image
# Uploaded n01532829_12137.JPEG to image
# Uploaded n01532829_12141.JPEG to image
# Uploaded n01532829_1216.JPEG to image
# Uploaded n01532829_12187.JPEG to image
# Uploaded n01532829_122.JPEG to image
# Uploaded n01532829_12280.JPEG to image
# Uploaded n01532829_12334.JPEG to image
# Uploaded n01532829_12382.JPEG to image
# Uploaded n01532829_124.JPEG to image
# Uploaded n01532829_1244.JPEG to image
# Uploaded n01532829_12514.JPEG to image
# Uploaded n01532829_1252.JPEG to image
# Uploaded n01532829_126.JPEG to image
# Uploaded n01532829_1261.JPEG to image
# Uploaded n01532829_12657.JPEG to image
# Uploaded n01532829_12734.JPEG to image
# Uploaded n01532829_1278.JPEG to image
# Uploaded n01532829_12818.JPEG to image
# Uploaded n01532829_1286.JPEG to image
# Uploaded n01532829_12865.JPEG to image
# Uploaded n01532829_1305.JPEG to image
# Uploaded n01532829_13061.JPEG to image
# Uploaded n01532829_1311.JPEG to image
# Uploaded n01532829_1312.JPEG to image
# Uploaded n01532829_1314.JPEG to image
# Uploaded n01532829_1316.JPEG to image
# Uploaded n01532829_1318.JPEG to image
# Uploaded n01532829_1325.JPEG to image
# Uploaded n01532829_1329.JPEG to image
# Uploaded n01532829_13384.JPEG to image
# Uploaded n01532829_13437.JPEG to image
# Uploaded n01532829_13517.JPEG to image
# Uploaded n01532829_13524.JPEG to image
# Uploaded n01532829_13551.JPEG to image
# Uploaded n01532829_1359.JPEG to image
# Uploaded n01532829_136.JPEG to image
# Uploaded n01532829_13636.JPEG to image
# Uploaded n01532829_1364.JPEG to image
# Uploaded n01532829_13687.JPEG to image
# Uploaded n01532829_1369.JPEG to image
# Uploaded n01532829_13778.JPEG to image
# Uploaded n01532829_13809.JPEG to image
# Uploaded n01532829_13813.JPEG to image
# Uploaded n01532829_13852.JPEG to image
# Uploaded n01532829_13864.JPEG to image
# Uploaded n01532829_13890.JPEG to image
# Uploaded n01532829_13893.JPEG to image
# Uploaded n01532829_1391.JPEG to image
# Uploaded n01532829_14005.JPEG to image
# Uploaded n01532829_1410.JPEG to image
# Uploaded n01532829_14191.JPEG to image
# Uploaded n01532829_1421.JPEG to image
# Uploaded n01532829_14230.JPEG to image
# Uploaded n01532829_14385.JPEG to image
# Uploaded n01532829_1442.JPEG to image
# Uploaded n01532829_1449.JPEG to image
# Uploaded n01532829_145.JPEG to image
# Uploaded n01532829_1451.JPEG to image
# Uploaded n01532829_14533.JPEG to image
# Uploaded n01532829_1465.JPEG to image
# Uploaded n01532829_14664.JPEG to image
# Uploaded n01532829_14723.JPEG to image
# Uploaded n01532829_14733.JPEG to image
# Uploaded n01532829_14753.JPEG to image
# Uploaded n01532829_14804.JPEG to image
# Uploaded n01532829_14820.JPEG to image
# Uploaded n01532829_1494.JPEG to image
# Uploaded n01532829_15026.JPEG to image
# Uploaded n01532829_1503.JPEG to image
# Uploaded n01532829_1504.JPEG to image
# Uploaded n01532829_15082.JPEG to image
# Uploaded n01532829_15152.JPEG to image
# Uploaded n01532829_15193.JPEG to image
# Uploaded n01532829_15237.JPEG to image
# Uploaded n01532829_1537.JPEG to image
# Uploaded n01532829_15469.JPEG to image
# Uploaded n01532829_155.JPEG to image
# Uploaded n01532829_1552.JPEG to image
# Uploaded n01532829_1554.JPEG to image
# Uploaded n01532829_1558.JPEG to image
# Uploaded n01532829_15602.JPEG to image
# Uploaded n01532829_15851.JPEG to image
# Uploaded n01532829_15852.JPEG to image
# Uploaded n01532829_15860.JPEG to image
# Uploaded n01532829_1591.JPEG to image
# Uploaded n01532829_15927.JPEG to image
# Uploaded n01532829_1599.JPEG to image
# Uploaded n01532829_16058.JPEG to image
# Uploaded n01532829_16073.JPEG to image
# Uploaded n01532829_1618.JPEG to image
# Uploaded n01532829_16199.JPEG to image
# Uploaded n01532829_1623.JPEG to image
# Uploaded n01532829_16279.JPEG to image
# Uploaded n01532829_1634.JPEG to image
# Uploaded n01532829_16344.JPEG to image
# Uploaded n01532829_16397.JPEG to image
# Uploaded n01532829_16522.JPEG to image
# Uploaded n01532829_1664.JPEG to image
# Uploaded n01532829_1666.JPEG to image
# Uploaded n01532829_16689.JPEG to image
# Uploaded n01532829_16714.JPEG to image
# Uploaded n01532829_16942.JPEG to image
# Uploaded n01532829_1700.JPEG to image
# Uploaded n01532829_17108.JPEG to image
# Uploaded n01532829_17116.JPEG to image
# Uploaded n01532829_1729.JPEG to image
# Uploaded n01532829_17313.JPEG to image
# Uploaded n01532829_17649.JPEG to image
# Uploaded n01532829_1774.JPEG to image
# Uploaded n01532829_1778.JPEG to image
# Uploaded n01532829_17826.JPEG to image
# Uploaded n01532829_1784.JPEG to image
# Uploaded n01532829_17905.JPEG to image
# Uploaded n01532829_17969.JPEG to image
# Uploaded n01532829_17979.JPEG to image
# Uploaded n01532829_18023.JPEG to image
# Uploaded n01532829_18057.JPEG to image
# Uploaded n01532829_18410.JPEG to image
# Uploaded n01532829_1858.JPEG to image
# Uploaded n01532829_189.JPEG to image
# Uploaded n01532829_1902.JPEG to image
# Uploaded n01532829_19191.JPEG to image
# Uploaded n01532829_19306.JPEG to image
# Uploaded n01532829_19310.JPEG to image
# Uploaded n01532829_19417.JPEG to image
# Uploaded n01532829_1944.JPEG to image
# Uploaded n01532829_19477.JPEG to image
# Uploaded n01532829_1949.JPEG to image
# Uploaded n01532829_1960.JPEG to image
# Uploaded n01532829_1966.JPEG to image
# Uploaded n01532829_19864.JPEG to image
# Uploaded n01532829_19872.JPEG to image
# Uploaded n01532829_1990.JPEG to image
# Uploaded n01532829_1991.JPEG to image
# Uploaded n01532829_19977.JPEG to image
# Uploaded n01532829_20101.JPEG to image
# Uploaded n01532829_2011.JPEG to image
# Uploaded n01532829_2023.JPEG to image
# Uploaded n01532829_2024.JPEG to image
# Uploaded n01532829_2029.JPEG to image
# Uploaded n01532829_20318.JPEG to image
# Uploaded n01532829_20457.JPEG to image
# Uploaded n01532829_20524.JPEG to image
# Uploaded n01532829_20591.JPEG to image
# Uploaded n01532829_20599.JPEG to image
# Uploaded n01532829_2112.JPEG to image
# Uploaded n01532829_21122.JPEG to image
# Uploaded n01532829_2113.JPEG to image
# Uploaded n01532829_2119.JPEG to image
# Uploaded n01532829_2121.JPEG to image
# Uploaded n01532829_2123.JPEG to image
# Uploaded n01532829_21278.JPEG to image
# Uploaded n01532829_2132.JPEG to image
# Uploaded n01532829_2136.JPEG to image
# Uploaded n01532829_2141.JPEG to image
# Uploaded n01532829_2145.JPEG to image
# Uploaded n01532829_21608.JPEG to image
# Uploaded n01532829_21692.JPEG to image
# Uploaded n01532829_2170.JPEG to image
# Uploaded n01532829_2174.JPEG to image
# Uploaded n01532829_21740.JPEG to image
# Uploaded n01532829_21800.JPEG to image
# Uploaded n01532829_21817.JPEG to image
# Uploaded n01532829_21824.JPEG to image
# Uploaded n01532829_21915.JPEG to image
# Uploaded n01532829_21929.JPEG to image
# Uploaded n01532829_22218.JPEG to image
# Uploaded n01532829_2229.JPEG to image
# Uploaded n01532829_22299.JPEG to image
# Uploaded n01532829_22390.JPEG to image
# Uploaded n01532829_2246.JPEG to image
# Uploaded n01532829_2248.JPEG to image
# Uploaded n01532829_225.JPEG to image
# Uploaded n01532829_22583.JPEG to image
# Uploaded n01532829_2263.JPEG to image
# Uploaded n01532829_22650.JPEG to image
# Uploaded n01532829_2270.JPEG to image
# Uploaded n01532829_22797.JPEG to image
# Uploaded n01532829_22963.JPEG to image
# Uploaded n01532829_2324.JPEG to image
# Uploaded n01532829_2326.JPEG to image
# Uploaded n01532829_23313.JPEG to image
# Uploaded n01532829_2340.JPEG to image
# Uploaded n01532829_2341.JPEG to image
# Uploaded n01532829_2349.JPEG to image
# Uploaded n01532829_2352.JPEG to image
# Uploaded n01532829_2368.JPEG to image
# Uploaded n01532829_23825.JPEG to image
# Uploaded n01532829_23895.JPEG to image
# Uploaded n01532829_23950.JPEG to image
# Uploaded n01532829_2399.JPEG to image
# Uploaded n01532829_242.JPEG to image
# Uploaded n01532829_24266.JPEG to image
# Uploaded n01532829_243.JPEG to image
# Uploaded n01532829_24308.JPEG to image
# Uploaded n01532829_24363.JPEG to image
# Uploaded n01532829_2439.JPEG to image
# Uploaded n01532829_2440.JPEG to image
# Uploaded n01532829_2453.JPEG to image
# Uploaded n01532829_24649.JPEG to image
# Uploaded n01532829_2472.JPEG to image
# Uploaded n01532829_2492.JPEG to image
# Uploaded n01532829_25068.JPEG to image
# Uploaded n01532829_251.JPEG to image
# Uploaded n01532829_2518.JPEG to image
# Uploaded n01532829_25241.JPEG to image
# Uploaded n01532829_25250.JPEG to image
# Uploaded n01532829_25303.JPEG to image
# Uploaded n01532829_25329.JPEG to image
# Uploaded n01532829_2536.JPEG to image
# Uploaded n01532829_254.JPEG to image
# Uploaded n01532829_25406.JPEG to image
# Uploaded n01532829_2547.JPEG to image
# Uploaded n01532829_2564.JPEG to image
# Uploaded n01532829_259.JPEG to image
# Uploaded n01532829_2592.JPEG to image
# Uploaded n01532829_2601.JPEG to image
# Uploaded n01532829_261.JPEG to image
# Uploaded n01532829_2614.JPEG to image
# Uploaded n01532829_2615.JPEG to image
# Uploaded n01532829_26194.JPEG to image
# Uploaded n01532829_26210.JPEG to image
# Uploaded n01532829_26212.JPEG to image
# Uploaded n01532829_2627.JPEG to image
# Uploaded n01532829_26407.JPEG to image
# Uploaded n01532829_26427.JPEG to image
# Uploaded n01532829_2658.JPEG to image
# Uploaded n01532829_26581.JPEG to image
# Uploaded n01532829_2672.JPEG to image
# Uploaded n01532829_26721.JPEG to image
# Uploaded n01532829_26796.JPEG to image
# Uploaded n01532829_268.JPEG to image
# Uploaded n01532829_2681.JPEG to image
# Uploaded n01532829_2703.JPEG to image
# Uploaded n01532829_271.JPEG to image
# Uploaded n01532829_27119.JPEG to image
# Uploaded n01532829_27161.JPEG to image
# Uploaded n01532829_2722.JPEG to image
# Uploaded n01532829_27264.JPEG to image
# Uploaded n01532829_2733.JPEG to image
# Uploaded n01532829_2748.JPEG to image
# Uploaded n01532829_27525.JPEG to image
# Uploaded n01532829_2765.JPEG to image
# Uploaded n01532829_2769.JPEG to image
# Uploaded n01532829_2792.JPEG to image
# Uploaded n01532829_27980.JPEG to image
# Uploaded n01532829_28.JPEG to image
# Uploaded n01532829_2800.JPEG to image
# Uploaded n01532829_28047.JPEG to image
# Uploaded n01532829_2813.JPEG to image
# Uploaded n01532829_2814.JPEG to image
# Uploaded n01532829_2831.JPEG to image
# Uploaded n01532829_28340.JPEG to image
# Uploaded n01532829_2837.JPEG to image
# Uploaded n01532829_2847.JPEG to image
# Uploaded n01532829_2857.JPEG to image
# Uploaded n01532829_2862.JPEG to image
# Uploaded n01532829_28650.JPEG to image
# Uploaded n01532829_287.JPEG to image
# Uploaded n01532829_28722.JPEG to image
# Uploaded n01532829_28786.JPEG to image
# Uploaded n01532829_28930.JPEG to image
# Uploaded n01532829_29073.JPEG to image
# Uploaded n01532829_29159.JPEG to image
# Uploaded n01532829_29218.JPEG to image
# Uploaded n01532829_2924.JPEG to image
# Uploaded n01532829_29328.JPEG to image
# Uploaded n01532829_2935.JPEG to image
# Uploaded n01532829_29477.JPEG to image
# Uploaded n01532829_2954.JPEG to image
# Uploaded n01532829_298.JPEG to image
# Uploaded n01532829_29860.JPEG to image
# Uploaded n01532829_29893.JPEG to image
# Uploaded n01532829_29988.JPEG to image
# Uploaded n01532829_30006.JPEG to image
# Uploaded n01532829_30033.JPEG to image
# Uploaded n01532829_30090.JPEG to image
# Uploaded n01532829_3035.JPEG to image
# Uploaded n01532829_304.JPEG to image
# Uploaded n01532829_30432.JPEG to image
# Uploaded n01532829_30445.JPEG to image
# Uploaded n01532829_307.JPEG to image
# Uploaded n01532829_3092.JPEG to image
# Uploaded n01532829_31207.JPEG to image
# Uploaded n01532829_3126.JPEG to image
# Uploaded n01532829_31263.JPEG to image
# Uploaded n01532829_31339.JPEG to image
# Uploaded n01532829_3135.JPEG to image
# Uploaded n01532829_31404.JPEG to image
# Uploaded n01532829_3145.JPEG to image
# Uploaded n01532829_3156.JPEG to image
# Uploaded n01532829_31588.JPEG to image
# Uploaded n01532829_31867.JPEG to image
# Uploaded n01532829_319.JPEG to image
# Uploaded n01532829_31947.JPEG to image
# Uploaded n01532829_31950.JPEG to image
# Uploaded n01532829_3201.JPEG to image
# Uploaded n01532829_32103.JPEG to image
# Uploaded n01532829_3217.JPEG to image
# Uploaded n01532829_3223.JPEG to image
# Uploaded n01532829_32299.JPEG to image
# Uploaded n01532829_3238.JPEG to image
# Uploaded n01532829_3246.JPEG to image
# Uploaded n01532829_32670.JPEG to image
# Uploaded n01532829_3268.JPEG to image
# Uploaded n01532829_32723.JPEG to image
# Uploaded n01532829_3281.JPEG to image
# Uploaded n01532829_3284.JPEG to image
# Uploaded n01532829_32847.JPEG to image
# Uploaded n01532829_3286.JPEG to image
# Uploaded n01532829_3287.JPEG to image
# Uploaded n01532829_3288.JPEG to image
# Uploaded n01532829_3303.JPEG to image
# Uploaded n01532829_33069.JPEG to image
# Uploaded n01532829_33179.JPEG to image
# Uploaded n01532829_33220.JPEG to image
# Uploaded n01532829_33412.JPEG to image
# Uploaded n01532829_3349.JPEG to image
# Uploaded n01532829_33517.JPEG to image
# Uploaded n01532829_3370.JPEG to image
# Uploaded n01532829_33799.JPEG to image
# Uploaded n01532829_33928.JPEG to image
# Uploaded n01532829_33940.JPEG to image
# Uploaded n01532829_3398.JPEG to image
# Uploaded n01532829_340.JPEG to image
# Uploaded n01532829_3404.JPEG to image
# Uploaded n01532829_3408.JPEG to image
# Uploaded n01532829_34145.JPEG to image
# Uploaded n01532829_3420.JPEG to image
# Uploaded n01532829_3429.JPEG to image
# Uploaded n01532829_3434.JPEG to image
# Uploaded n01532829_3436.JPEG to image
# Uploaded n01532829_344.JPEG to image
# Uploaded n01532829_3442.JPEG to image
# Uploaded n01532829_3444.JPEG to image
# Uploaded n01532829_3451.JPEG to image
# Uploaded n01532829_3459.JPEG to image
# Uploaded n01532829_34741.JPEG to image
# Uploaded n01532829_34864.JPEG to image
# Uploaded n01532829_34865.JPEG to image
# Uploaded n01532829_34883.JPEG to image
# Uploaded n01532829_3531.JPEG to image
# Uploaded n01532829_35391.JPEG to image
# Uploaded n01532829_35962.JPEG to image
# Uploaded n01532829_3597.JPEG to image
# Uploaded n01532829_3607.JPEG to image
# Uploaded n01532829_36113.JPEG to image
# Uploaded n01532829_3623.JPEG to image
# Uploaded n01532829_3636.JPEG to image
# Uploaded n01532829_36459.JPEG to image
# Uploaded n01532829_36467.JPEG to image
# Uploaded n01532829_3649.JPEG to image
# Uploaded n01532829_3650.JPEG to image
# Uploaded n01532829_36564.JPEG to image
# Uploaded n01532829_36628.JPEG to image
# Uploaded n01532829_3671.JPEG to image
# Uploaded n01532829_3672.JPEG to image
# Uploaded n01532829_36789.JPEG to image
# Uploaded n01532829_3685.JPEG to image
# Uploaded n01532829_36871.JPEG to image
# Uploaded n01532829_37106.JPEG to image
# Uploaded n01532829_37319.JPEG to image
# Uploaded n01532829_3736.JPEG to image
# Uploaded n01532829_37571.JPEG to image
# Uploaded n01532829_37697.JPEG to image
# Uploaded n01532829_37770.JPEG to image
# Uploaded n01532829_37821.JPEG to image
# Uploaded n01532829_3808.JPEG to image
# Uploaded n01532829_3815.JPEG to image
# Uploaded n01532829_38225.JPEG to image
# Uploaded n01532829_3833.JPEG to image
# Uploaded n01532829_38445.JPEG to image
# Uploaded n01532829_38534.JPEG to image
# Uploaded n01532829_38601.JPEG to image
# Uploaded n01532829_38643.JPEG to image
# Uploaded n01532829_3867.JPEG to image
# Uploaded n01532829_3874.JPEG to image
# Uploaded n01532829_3884.JPEG to image
# Uploaded n01532829_39091.JPEG to image
# Uploaded n01532829_3913.JPEG to image
# Uploaded n01532829_3914.JPEG to image
# Uploaded n01532829_39140.JPEG to image
# Uploaded n01532829_39203.JPEG to image
# Uploaded n01532829_393.JPEG to image
# Uploaded n01532829_3967.JPEG to image
# Uploaded n01532829_3989.JPEG to image
# Uploaded n01532829_3998.JPEG to image
# Uploaded n01532829_403.JPEG to image
# Uploaded n01532829_4038.JPEG to image
# Uploaded n01532829_4065.JPEG to image
# Uploaded n01532829_4090.JPEG to image
# Uploaded n01532829_4096.JPEG to image
# Uploaded n01532829_4127.JPEG to image
# Uploaded n01532829_4179.JPEG to image
# Uploaded n01532829_418.JPEG to image
# Uploaded n01532829_4195.JPEG to image
# Uploaded n01532829_4237.JPEG to image
# Uploaded n01532829_4319.JPEG to image
# Uploaded n01532829_4331.JPEG to image
# Uploaded n01532829_4340.JPEG to image
# Uploaded n01532829_436.JPEG to image
# Uploaded n01532829_4384.JPEG to image
# Uploaded n01532829_439.JPEG to image
# Uploaded n01532829_441.JPEG to image
# Uploaded n01532829_4413.JPEG to image
# Uploaded n01532829_4422.JPEG to image
# Uploaded n01532829_4434.JPEG to image
# Uploaded n01532829_4455.JPEG to image
# Uploaded n01532829_447.JPEG to image
# Uploaded n01532829_4497.JPEG to image
# Uploaded n01532829_4536.JPEG to image
# Uploaded n01532829_4546.JPEG to image
# Uploaded n01532829_4562.JPEG to image
# Uploaded n01532829_457.JPEG to image
# Uploaded n01532829_4587.JPEG to image
# Uploaded n01532829_4611.JPEG to image
# Uploaded n01532829_4616.JPEG to image
# Uploaded n01532829_464.JPEG to image
# Uploaded n01532829_4691.JPEG to image
# Uploaded n01532829_4695.JPEG to image
# Uploaded n01532829_47.JPEG to image
# Uploaded n01532829_4722.JPEG to image
# Uploaded n01532829_4723.JPEG to image
# Uploaded n01532829_4745.JPEG to image
# Uploaded n01532829_4749.JPEG to image
# Uploaded n01532829_478.JPEG to image
# Uploaded n01532829_4786.JPEG to image
# Uploaded n01532829_4796.JPEG to image
# Uploaded n01532829_481.JPEG to image
# Uploaded n01532829_4810.JPEG to image
# Uploaded n01532829_4821.JPEG to image
# Uploaded n01532829_4826.JPEG to image
# Uploaded n01532829_4850.JPEG to image
# Uploaded n01532829_4893.JPEG to image
# Uploaded n01532829_4926.JPEG to image
# Uploaded n01532829_4947.JPEG to image
# Uploaded n01532829_495.JPEG to image
# Uploaded n01532829_4973.JPEG to image
# Uploaded n01532829_4980.JPEG to image
# Uploaded n01532829_499.JPEG to image
# Uploaded n01532829_4994.JPEG to image
# Uploaded n01532829_5001.JPEG to image
# Uploaded n01532829_5002.JPEG to image
# Uploaded n01532829_5059.JPEG to image
# Uploaded n01532829_5079.JPEG to image
# Uploaded n01532829_5096.JPEG to image
# Uploaded n01532829_5131.JPEG to image
# Uploaded n01532829_5147.JPEG to image
# Uploaded n01532829_5159.JPEG to image
# Uploaded n01532829_5160.JPEG to image
# Uploaded n01532829_5177.JPEG to image
# Uploaded n01532829_521.JPEG to image
# Uploaded n01532829_5210.JPEG to image
# Uploaded n01532829_524.JPEG to image
# Uploaded n01532829_5294.JPEG to image
# Uploaded n01532829_5300.JPEG to image
# Uploaded n01532829_5321.JPEG to image
# Uploaded n01532829_5356.JPEG to image
# Uploaded n01532829_5357.JPEG to image
# Uploaded n01532829_5402.JPEG to image
# Uploaded n01532829_5403.JPEG to image
# Uploaded n01532829_5419.JPEG to image
# Uploaded n01532829_5443.JPEG to image
# Uploaded n01532829_5472.JPEG to image
# Uploaded n01532829_5489.JPEG to image
# Uploaded n01532829_55.JPEG to image
# Uploaded n01532829_5531.JPEG to image
# Uploaded n01532829_5532.JPEG to image
# Uploaded n01532829_5535.JPEG to image
# Uploaded n01532829_5556.JPEG to image
# Uploaded n01532829_5561.JPEG to image
# Uploaded n01532829_559.JPEG to image
# Uploaded n01532829_5641.JPEG to image
# Uploaded n01532829_5647.JPEG to image
# Uploaded n01532829_5669.JPEG to image
# Uploaded n01532829_5680.JPEG to image
# Uploaded n01532829_5696.JPEG to image
# Uploaded n01532829_5708.JPEG to image
# Uploaded n01532829_5712.JPEG to image
# Uploaded n01532829_5720.JPEG to image
# Uploaded n01532829_5841.JPEG to image
# Uploaded n01532829_585.JPEG to image
# Uploaded n01532829_5869.JPEG to image
# Uploaded n01532829_5891.JPEG to image
# Uploaded n01532829_5903.JPEG to image
# Uploaded n01532829_5910.JPEG to image
# Uploaded n01532829_5911.JPEG to image
# Uploaded n01532829_5914.JPEG to image
# Uploaded n01532829_5915.JPEG to image
# Uploaded n01532829_5919.JPEG to image
# Uploaded n01532829_5950.JPEG to image
# Uploaded n01532829_5983.JPEG to image
# Uploaded n01532829_6003.JPEG to image
# Uploaded n01532829_6025.JPEG to image
# Uploaded n01532829_622.JPEG to image
# Uploaded n01532829_6226.JPEG to image
# Uploaded n01532829_6388.JPEG to image
# Uploaded n01532829_643.JPEG to image
# Uploaded n01532829_6501.JPEG to image
# Uploaded n01532829_680.JPEG to image
# Uploaded n01532829_685.JPEG to image
# Uploaded n01532829_686.JPEG to image
# Uploaded n01532829_6888.JPEG to image
# Uploaded n01532829_6932.JPEG to image
# Uploaded n01532829_712.JPEG to image
# Uploaded n01532829_7129.JPEG to image
# Uploaded n01532829_716.JPEG to image
# Uploaded n01532829_721.JPEG to image
# Uploaded n01532829_7219.JPEG to image
# Uploaded n01532829_7378.JPEG to image
# Uploaded n01532829_7398.JPEG to image
# Uploaded n01532829_741.JPEG to image
# Uploaded n01532829_742.JPEG to image
# Uploaded n01532829_7480.JPEG to image
# Uploaded n01532829_7483.JPEG to image
# Uploaded n01532829_7487.JPEG to image
# Uploaded n01532829_7606.JPEG to image
# Uploaded n01532829_7607.JPEG to image
# Uploaded n01532829_762.JPEG to image
# Uploaded n01532829_7666.JPEG to image
# Uploaded n01532829_7809.JPEG to image
# Uploaded n01532829_7845.JPEG to image
# Uploaded n01532829_7884.JPEG to image
# Uploaded n01532829_8055.JPEG to image
# Uploaded n01532829_812.JPEG to image
# Uploaded n01532829_82.JPEG to image
# Uploaded n01532829_8222.JPEG to image
# Uploaded n01532829_8235.JPEG to image
# Uploaded n01532829_8281.JPEG to image
# Uploaded n01532829_8316.JPEG to image
# Uploaded n01532829_835.JPEG to image
# Uploaded n01532829_8371.JPEG to image
# Uploaded n01532829_8414.JPEG to image
# Uploaded n01532829_8439.JPEG to image
# Uploaded n01532829_845.JPEG to image
# Uploaded n01532829_849.JPEG to image
# Uploaded n01532829_856.JPEG to image
# Uploaded n01532829_8622.JPEG to image
# Uploaded n01532829_870.JPEG to image
# Uploaded n01532829_873.JPEG to image
# Uploaded n01532829_880.JPEG to image
# Uploaded n01532829_8809.JPEG to image
# Uploaded n01532829_886.JPEG to image
# Uploaded n01532829_900.JPEG to image
# Uploaded n01532829_914.JPEG to image
# Uploaded n01532829_9158.JPEG to image
# Uploaded n01532829_917.JPEG to image
# Uploaded n01532829_9179.JPEG to image
# Uploaded n01532829_9212.JPEG to image
# Uploaded n01532829_9218.JPEG to image
# Uploaded n01532829_930.JPEG to image
# Uploaded n01532829_935.JPEG to image
# Uploaded n01532829_9441.JPEG to image
# Uploaded n01532829_947.JPEG to image
# Uploaded n01532829_9550.JPEG to image
# Uploaded n01532829_958.JPEG to image
# Uploaded n01532829_962.JPEG to image
# Uploaded n01532829_966.JPEG to image
# Uploaded n01532829_976.JPEG to image
# Uploaded n01532829_978.JPEG to image
# Uploaded n01532829_998.JPEG to image
# ./miniImageNet\n01558993
# Uploaded n01558993_10153.JPEG to image
# Uploaded n01558993_10175.JPEG to image
# Uploaded n01558993_10268.JPEG to image
# Uploaded n01558993_10351.JPEG to image
# Uploaded n01558993_10376.JPEG to image
# Uploaded n01558993_10442.JPEG to image
# Uploaded n01558993_10514.JPEG to image
# Uploaded n01558993_10530.JPEG to image
# Uploaded n01558993_10575.JPEG to image
# Uploaded n01558993_10606.JPEG to image
# Uploaded n01558993_10621.JPEG to image
# Uploaded n01558993_10809.JPEG to image
# Uploaded n01558993_10835.JPEG to image
# Uploaded n01558993_10838.JPEG to image
# Uploaded n01558993_10851.JPEG to image
# Uploaded n01558993_10913.JPEG to image
# Uploaded n01558993_10931.JPEG to image
# Uploaded n01558993_11087.JPEG to image
# Uploaded n01558993_11093.JPEG to image
# Uploaded n01558993_11167.JPEG to image
# Uploaded n01558993_11181.JPEG to image
# Uploaded n01558993_11185.JPEG to image
# Uploaded n01558993_11222.JPEG to image
# Uploaded n01558993_11240.JPEG to image
# Uploaded n01558993_1126.JPEG to image
# Uploaded n01558993_11309.JPEG to image
# Uploaded n01558993_11312.JPEG to image
# Uploaded n01558993_11314.JPEG to image
# Uploaded n01558993_1138.JPEG to image
# Uploaded n01558993_11384.JPEG to image
# Uploaded n01558993_11413.JPEG to image
# Uploaded n01558993_1147.JPEG to image
# Uploaded n01558993_11482.JPEG to image
# Uploaded n01558993_11517.JPEG to image
# Uploaded n01558993_11656.JPEG to image
# Uploaded n01558993_1174.JPEG to image
# Uploaded n01558993_11751.JPEG to image
# Uploaded n01558993_11752.JPEG to image
# Uploaded n01558993_11757.JPEG to image
# Uploaded n01558993_11769.JPEG to image
# Uploaded n01558993_1177.JPEG to image
# Uploaded n01558993_11796.JPEG to image
# Uploaded n01558993_118.JPEG to image
# Uploaded n01558993_11819.JPEG to image
# Uploaded n01558993_11843.JPEG to image
# Uploaded n01558993_11847.JPEG to image
# Uploaded n01558993_11899.JPEG to image
# Uploaded n01558993_11900.JPEG to image
# Uploaded n01558993_11913.JPEG to image
# Uploaded n01558993_11918.JPEG to image
# Uploaded n01558993_11939.JPEG to image
# Uploaded n01558993_11951.JPEG to image
# Uploaded n01558993_11984.JPEG to image
# Uploaded n01558993_12012.JPEG to image
# Uploaded n01558993_12084.JPEG to image
# Uploaded n01558993_12165.JPEG to image
# Uploaded n01558993_12176.JPEG to image
# Uploaded n01558993_12204.JPEG to image
# Uploaded n01558993_12210.JPEG to image
# Uploaded n01558993_12231.JPEG to image
# Uploaded n01558993_12245.JPEG to image
# Uploaded n01558993_12255.JPEG to image
# Uploaded n01558993_12272.JPEG to image
# Uploaded n01558993_12321.JPEG to image
# Uploaded n01558993_12337.JPEG to image
# Uploaded n01558993_12368.JPEG to image
# Uploaded n01558993_12465.JPEG to image
# Uploaded n01558993_12476.JPEG to image
# Uploaded n01558993_12504.JPEG to image
# Uploaded n01558993_12535.JPEG to image
# Uploaded n01558993_12544.JPEG to image
# Uploaded n01558993_12588.JPEG to image
# Uploaded n01558993_12598.JPEG to image
# Uploaded n01558993_12674.JPEG to image
# Uploaded n01558993_12692.JPEG to image
# Uploaded n01558993_12694.JPEG to image
# Uploaded n01558993_12721.JPEG to image
# Uploaded n01558993_1274.JPEG to image
# Uploaded n01558993_12740.JPEG to image
# Uploaded n01558993_12743.JPEG to image
# Uploaded n01558993_1280.JPEG to image
# Uploaded n01558993_12808.JPEG to image
# Uploaded n01558993_12826.JPEG to image
# Uploaded n01558993_12846.JPEG to image
# Uploaded n01558993_12897.JPEG to image
# Uploaded n01558993_12927.JPEG to image
# Uploaded n01558993_12930.JPEG to image
# Uploaded n01558993_12968.JPEG to image
# Uploaded n01558993_12972.JPEG to image
# Uploaded n01558993_13067.JPEG to image
# Uploaded n01558993_1308.JPEG to image
# Uploaded n01558993_13092.JPEG to image
# Uploaded n01558993_13116.JPEG to image
# Uploaded n01558993_13118.JPEG to image
# Uploaded n01558993_13178.JPEG to image
# Uploaded n01558993_13196.JPEG to image
# Uploaded n01558993_13225.JPEG to image
# Uploaded n01558993_13259.JPEG to image
# Uploaded n01558993_13274.JPEG to image
# Uploaded n01558993_13276.JPEG to image
# Uploaded n01558993_13294.JPEG to image
# Uploaded n01558993_13332.JPEG to image
# Uploaded n01558993_13360.JPEG to image
# Uploaded n01558993_13384.JPEG to image
# Uploaded n01558993_13386.JPEG to image
# Uploaded n01558993_13390.JPEG to image
# Uploaded n01558993_13396.JPEG to image
# Uploaded n01558993_13402.JPEG to image
# Uploaded n01558993_13419.JPEG to image
# Uploaded n01558993_13427.JPEG to image
# Uploaded n01558993_13445.JPEG to image
# Uploaded n01558993_13452.JPEG to image
# Uploaded n01558993_13466.JPEG to image
# Uploaded n01558993_13567.JPEG to image
# Uploaded n01558993_13570.JPEG to image
# Uploaded n01558993_13586.JPEG to image
# Uploaded n01558993_13629.JPEG to image
# Uploaded n01558993_1363.JPEG to image
# Uploaded n01558993_13636.JPEG to image
# Uploaded n01558993_13652.JPEG to image
# Uploaded n01558993_13734.JPEG to image
# Uploaded n01558993_13739.JPEG to image
# Uploaded n01558993_13747.JPEG to image
# Uploaded n01558993_13790.JPEG to image
# Uploaded n01558993_13824.JPEG to image
# Uploaded n01558993_13852.JPEG to image
# Uploaded n01558993_1386.JPEG to image
# Uploaded n01558993_13988.JPEG to image
# Uploaded n01558993_14000.JPEG to image
# Uploaded n01558993_14032.JPEG to image
# Uploaded n01558993_14088.JPEG to image
# Uploaded n01558993_14115.JPEG to image
# Uploaded n01558993_14116.JPEG to image
# Uploaded n01558993_14118.JPEG to image
# Uploaded n01558993_14124.JPEG to image
# Uploaded n01558993_14181.JPEG to image
# Uploaded n01558993_14247.JPEG to image
# Uploaded n01558993_14257.JPEG to image
# Uploaded n01558993_14271.JPEG to image
# Uploaded n01558993_14281.JPEG to image
# Uploaded n01558993_14305.JPEG to image
# Uploaded n01558993_14319.JPEG to image
# Uploaded n01558993_14328.JPEG to image
# Uploaded n01558993_14339.JPEG to image
# Uploaded n01558993_1434.JPEG to image
# Uploaded n01558993_1435.JPEG to image
# Uploaded n01558993_1436.JPEG to image
# Uploaded n01558993_14360.JPEG to image
# Uploaded n01558993_14392.JPEG to image
# Uploaded n01558993_1442.JPEG to image
# Uploaded n01558993_14443.JPEG to image
# Uploaded n01558993_14448.JPEG to image
# Uploaded n01558993_14470.JPEG to image
# Uploaded n01558993_14473.JPEG to image
# Uploaded n01558993_14526.JPEG to image
# Uploaded n01558993_1454.JPEG to image
# Uploaded n01558993_14592.JPEG to image
# Uploaded n01558993_146.JPEG to image
# Uploaded n01558993_14609.JPEG to image
# Uploaded n01558993_14664.JPEG to image
# Uploaded n01558993_14666.JPEG to image
# Uploaded n01558993_14669.JPEG to image
# Uploaded n01558993_14684.JPEG to image
# Uploaded n01558993_14698.JPEG to image
# Uploaded n01558993_14723.JPEG to image
# Uploaded n01558993_14729.JPEG to image
# Uploaded n01558993_14735.JPEG to image
# Uploaded n01558993_1479.JPEG to image
# Uploaded n01558993_14798.JPEG to image
# Uploaded n01558993_1499.JPEG to image
# Uploaded n01558993_1500.JPEG to image
# Uploaded n01558993_1501.JPEG to image
# Uploaded n01558993_1516.JPEG to image
# Uploaded n01558993_15254.JPEG to image
# Uploaded n01558993_1549.JPEG to image
# Uploaded n01558993_155.JPEG to image
# Uploaded n01558993_1550.JPEG to image
# Uploaded n01558993_1563.JPEG to image
# Uploaded n01558993_15679.JPEG to image
# Uploaded n01558993_1578.JPEG to image
# Uploaded n01558993_15905.JPEG to image
# Uploaded n01558993_15950.JPEG to image
# Uploaded n01558993_16031.JPEG to image
# Uploaded n01558993_16039.JPEG to image
# Uploaded n01558993_1608.JPEG to image
# Uploaded n01558993_16197.JPEG to image
# Uploaded n01558993_16352.JPEG to image
# Uploaded n01558993_16414.JPEG to image
# Uploaded n01558993_16439.JPEG to image
# Uploaded n01558993_16519.JPEG to image
# Uploaded n01558993_16531.JPEG to image
# Uploaded n01558993_1660.JPEG to image
# Uploaded n01558993_16650.JPEG to image
# Uploaded n01558993_1666.JPEG to image
# Uploaded n01558993_16860.JPEG to image
# Uploaded n01558993_17000.JPEG to image
# Uploaded n01558993_1712.JPEG to image
# Uploaded n01558993_17192.JPEG to image
# Uploaded n01558993_17264.JPEG to image
# Uploaded n01558993_17341.JPEG to image
# Uploaded n01558993_1760.JPEG to image
# Uploaded n01558993_17617.JPEG to image
# Uploaded n01558993_177.JPEG to image
# Uploaded n01558993_1770.JPEG to image
# Uploaded n01558993_17784.JPEG to image
# Uploaded n01558993_17793.JPEG to image
# Uploaded n01558993_18147.JPEG to image
# Uploaded n01558993_18151.JPEG to image
# Uploaded n01558993_18232.JPEG to image
# Uploaded n01558993_18329.JPEG to image
# Uploaded n01558993_18442.JPEG to image
# Uploaded n01558993_18535.JPEG to image
# Uploaded n01558993_1868.JPEG to image
# Uploaded n01558993_18740.JPEG to image
# Uploaded n01558993_18833.JPEG to image
# Uploaded n01558993_18932.JPEG to image
# Uploaded n01558993_1895.JPEG to image
# Uploaded n01558993_190.JPEG to image
# Uploaded n01558993_1900.JPEG to image
# Uploaded n01558993_19149.JPEG to image
# Uploaded n01558993_1926.JPEG to image
# Uploaded n01558993_1932.JPEG to image
# Uploaded n01558993_1934.JPEG to image
# Uploaded n01558993_19451.JPEG to image
# Uploaded n01558993_19491.JPEG to image
# Uploaded n01558993_1961.JPEG to image
# Uploaded n01558993_19718.JPEG to image
# Uploaded n01558993_1980.JPEG to image
# Uploaded n01558993_19802.JPEG to image
# Uploaded n01558993_1983.JPEG to image
# Uploaded n01558993_19892.JPEG to image
# Uploaded n01558993_1993.JPEG to image
# Uploaded n01558993_19973.JPEG to image
# Uploaded n01558993_2059.JPEG to image
# Uploaded n01558993_2078.JPEG to image
# Uploaded n01558993_2080.JPEG to image
# Uploaded n01558993_2084.JPEG to image
# Uploaded n01558993_2090.JPEG to image
# Uploaded n01558993_2091.JPEG to image
# Uploaded n01558993_20937.JPEG to image
# Uploaded n01558993_2095.JPEG to image
# Uploaded n01558993_21.JPEG to image
# Uploaded n01558993_2111.JPEG to image
# Uploaded n01558993_2123.JPEG to image
# Uploaded n01558993_2126.JPEG to image
# Uploaded n01558993_21430.JPEG to image
# Uploaded n01558993_2173.JPEG to image
# Uploaded n01558993_21740.JPEG to image
# Uploaded n01558993_2182.JPEG to image
# Uploaded n01558993_2202.JPEG to image
# Uploaded n01558993_2291.JPEG to image
# Uploaded n01558993_22926.JPEG to image
# Uploaded n01558993_2302.JPEG to image
# Uploaded n01558993_23042.JPEG to image
# Uploaded n01558993_2306.JPEG to image
# Uploaded n01558993_2316.JPEG to image
# Uploaded n01558993_2327.JPEG to image
# Uploaded n01558993_2336.JPEG to image
# Uploaded n01558993_2337.JPEG to image
# Uploaded n01558993_2338.JPEG to image
# Uploaded n01558993_2345.JPEG to image
# Uploaded n01558993_2373.JPEG to image
# Uploaded n01558993_2385.JPEG to image
# Uploaded n01558993_2408.JPEG to image
# Uploaded n01558993_2413.JPEG to image
# Uploaded n01558993_24155.JPEG to image
# Uploaded n01558993_24168.JPEG to image
# Uploaded n01558993_2447.JPEG to image
# Uploaded n01558993_2449.JPEG to image
# Uploaded n01558993_2468.JPEG to image
# Uploaded n01558993_247.JPEG to image
# Uploaded n01558993_2484.JPEG to image
# Uploaded n01558993_24888.JPEG to image
# Uploaded n01558993_2495.JPEG to image
# Uploaded n01558993_2498.JPEG to image
# Uploaded n01558993_2502.JPEG to image
# Uploaded n01558993_2513.JPEG to image
# Uploaded n01558993_2519.JPEG to image
# Uploaded n01558993_2520.JPEG to image
# Uploaded n01558993_2527.JPEG to image
# Uploaded n01558993_2532.JPEG to image
# Uploaded n01558993_2533.JPEG to image
# Uploaded n01558993_2550.JPEG to image
# Uploaded n01558993_256.JPEG to image
# Uploaded n01558993_2565.JPEG to image
# Uploaded n01558993_2586.JPEG to image
# Uploaded n01558993_2593.JPEG to image
# Uploaded n01558993_2609.JPEG to image
# Uploaded n01558993_2619.JPEG to image
# Uploaded n01558993_2624.JPEG to image
# Uploaded n01558993_2637.JPEG to image
# Uploaded n01558993_2688.JPEG to image
# Uploaded n01558993_2690.JPEG to image
# Uploaded n01558993_2718.JPEG to image
# Uploaded n01558993_2724.JPEG to image
# Uploaded n01558993_2748.JPEG to image
# Uploaded n01558993_2760.JPEG to image
# Uploaded n01558993_2826.JPEG to image
# Uploaded n01558993_2866.JPEG to image
# Uploaded n01558993_2928.JPEG to image
# Uploaded n01558993_2954.JPEG to image
# Uploaded n01558993_2988.JPEG to image
# Uploaded n01558993_2995.JPEG to image
# Uploaded n01558993_3.JPEG to image
# Uploaded n01558993_3033.JPEG to image
# Uploaded n01558993_3068.JPEG to image
# Uploaded n01558993_3077.JPEG to image
# Uploaded n01558993_31.JPEG to image
# Uploaded n01558993_3125.JPEG to image
# Uploaded n01558993_3152.JPEG to image
# Uploaded n01558993_3159.JPEG to image
# Uploaded n01558993_31659.JPEG to image
# Uploaded n01558993_3174.JPEG to image
# Uploaded n01558993_3220.JPEG to image
# Uploaded n01558993_3222.JPEG to image
# Uploaded n01558993_3224.JPEG to image
# Uploaded n01558993_3234.JPEG to image
# Uploaded n01558993_3238.JPEG to image
# Uploaded n01558993_3269.JPEG to image
# Uploaded n01558993_3271.JPEG to image
# Uploaded n01558993_3306.JPEG to image
# Uploaded n01558993_3329.JPEG to image
# Uploaded n01558993_3334.JPEG to image
# Uploaded n01558993_3350.JPEG to image
# Uploaded n01558993_3352.JPEG to image
# Uploaded n01558993_33567.JPEG to image
# Uploaded n01558993_3359.JPEG to image
# Uploaded n01558993_3373.JPEG to image
# Uploaded n01558993_3398.JPEG to image
# Uploaded n01558993_3403.JPEG to image
# Uploaded n01558993_3405.JPEG to image
# Uploaded n01558993_3407.JPEG to image
# Uploaded n01558993_3408.JPEG to image
# Uploaded n01558993_3428.JPEG to image
# Uploaded n01558993_3467.JPEG to image
# Uploaded n01558993_3478.JPEG to image
# Uploaded n01558993_34885.JPEG to image
# Uploaded n01558993_350.JPEG to image
# Uploaded n01558993_3503.JPEG to image
# Uploaded n01558993_3506.JPEG to image
# Uploaded n01558993_3508.JPEG to image
# Uploaded n01558993_3519.JPEG to image
# Uploaded n01558993_3523.JPEG to image
# Uploaded n01558993_35443.JPEG to image
# Uploaded n01558993_3552.JPEG to image
# Uploaded n01558993_3553.JPEG to image
# Uploaded n01558993_3558.JPEG to image
# Uploaded n01558993_35727.JPEG to image
# Uploaded n01558993_3592.JPEG to image
# Uploaded n01558993_3593.JPEG to image
# Uploaded n01558993_3623.JPEG to image
# Uploaded n01558993_3632.JPEG to image
# Uploaded n01558993_3638.JPEG to image
# Uploaded n01558993_364.JPEG to image
# Uploaded n01558993_3659.JPEG to image
# Uploaded n01558993_3668.JPEG to image
# Uploaded n01558993_3684.JPEG to image
# Uploaded n01558993_3748.JPEG to image
# Uploaded n01558993_3749.JPEG to image
# Uploaded n01558993_3764.JPEG to image
# Uploaded n01558993_3790.JPEG to image
# Uploaded n01558993_3792.JPEG to image
# Uploaded n01558993_3797.JPEG to image
# Uploaded n01558993_38080.JPEG to image
# Uploaded n01558993_3837.JPEG to image
# Uploaded n01558993_3848.JPEG to image
# Uploaded n01558993_3849.JPEG to image
# Uploaded n01558993_3851.JPEG to image
# Uploaded n01558993_3870.JPEG to image
# Uploaded n01558993_3899.JPEG to image
# Uploaded n01558993_3906.JPEG to image
# Uploaded n01558993_3914.JPEG to image
# Uploaded n01558993_3934.JPEG to image
# Uploaded n01558993_3939.JPEG to image
# Uploaded n01558993_3962.JPEG to image
# Uploaded n01558993_3999.JPEG to image
# Uploaded n01558993_4037.JPEG to image
# Uploaded n01558993_4047.JPEG to image
# Uploaded n01558993_4052.JPEG to image
# Uploaded n01558993_40707.JPEG to image
# Uploaded n01558993_4093.JPEG to image
# Uploaded n01558993_4117.JPEG to image
# Uploaded n01558993_4128.JPEG to image
# Uploaded n01558993_41383.JPEG to image
# Uploaded n01558993_4151.JPEG to image
# Uploaded n01558993_41556.JPEG to image
# Uploaded n01558993_425.JPEG to image
# Uploaded n01558993_42607.JPEG to image
# Uploaded n01558993_4272.JPEG to image
# Uploaded n01558993_42945.JPEG to image
# Uploaded n01558993_4297.JPEG to image
# Uploaded n01558993_4299.JPEG to image
# Uploaded n01558993_4304.JPEG to image
# Uploaded n01558993_4306.JPEG to image
# Uploaded n01558993_4315.JPEG to image
# Uploaded n01558993_4326.JPEG to image
# Uploaded n01558993_4327.JPEG to image
# Uploaded n01558993_4375.JPEG to image
# Uploaded n01558993_439.JPEG to image
# Uploaded n01558993_4396.JPEG to image
# Uploaded n01558993_43968.JPEG to image
# Uploaded n01558993_4418.JPEG to image
# Uploaded n01558993_4425.JPEG to image
# Uploaded n01558993_4430.JPEG to image
# Uploaded n01558993_4433.JPEG to image
# Uploaded n01558993_4443.JPEG to image
# Uploaded n01558993_4445.JPEG to image
# Uploaded n01558993_4465.JPEG to image
# Uploaded n01558993_4478.JPEG to image
# Uploaded n01558993_4488.JPEG to image
# Uploaded n01558993_4495.JPEG to image
# Uploaded n01558993_45089.JPEG to image
# Uploaded n01558993_4523.JPEG to image
# Uploaded n01558993_4531.JPEG to image
# Uploaded n01558993_4575.JPEG to image
# Uploaded n01558993_4577.JPEG to image
# Uploaded n01558993_4649.JPEG to image
# Uploaded n01558993_4657.JPEG to image
# Uploaded n01558993_4698.JPEG to image
# Uploaded n01558993_4732.JPEG to image
# Uploaded n01558993_4734.JPEG to image
# Uploaded n01558993_4758.JPEG to image
# Uploaded n01558993_4801.JPEG to image
# Uploaded n01558993_4910.JPEG to image
# Uploaded n01558993_4929.JPEG to image
# Uploaded n01558993_4970.JPEG to image
# Uploaded n01558993_5.JPEG to image
# Uploaded n01558993_5030.JPEG to image
# Uploaded n01558993_5031.JPEG to image
# Uploaded n01558993_5035.JPEG to image
# Uploaded n01558993_5038.JPEG to image
# Uploaded n01558993_5044.JPEG to image
# Uploaded n01558993_5049.JPEG to image
# Uploaded n01558993_5085.JPEG to image
# Uploaded n01558993_5092.JPEG to image
# Uploaded n01558993_5100.JPEG to image
# Uploaded n01558993_5141.JPEG to image
# Uploaded n01558993_5185.JPEG to image
# Uploaded n01558993_5208.JPEG to image
# Uploaded n01558993_5231.JPEG to image
# Uploaded n01558993_5237.JPEG to image
# Uploaded n01558993_5247.JPEG to image
# Uploaded n01558993_5265.JPEG to image
# Uploaded n01558993_5299.JPEG to image
# Uploaded n01558993_5310.JPEG to image
# Uploaded n01558993_5311.JPEG to image
# Uploaded n01558993_5323.JPEG to image
# Uploaded n01558993_5325.JPEG to image
# Uploaded n01558993_5333.JPEG to image
# Uploaded n01558993_5406.JPEG to image
# Uploaded n01558993_5415.JPEG to image
# Uploaded n01558993_5443.JPEG to image
# Uploaded n01558993_5465.JPEG to image
# Uploaded n01558993_5489.JPEG to image
# Uploaded n01558993_5509.JPEG to image
# Uploaded n01558993_552.JPEG to image
# Uploaded n01558993_5535.JPEG to image
# Uploaded n01558993_5543.JPEG to image
# Uploaded n01558993_5551.JPEG to image
# Uploaded n01558993_5552.JPEG to image
# Uploaded n01558993_5566.JPEG to image
# Uploaded n01558993_5645.JPEG to image
# Uploaded n01558993_5675.JPEG to image
# Uploaded n01558993_5744.JPEG to image
# Uploaded n01558993_5762.JPEG to image
# Uploaded n01558993_589.JPEG to image
# Uploaded n01558993_5933.JPEG to image
# Uploaded n01558993_5943.JPEG to image
# Uploaded n01558993_5960.JPEG to image
# Uploaded n01558993_5969.JPEG to image
# Uploaded n01558993_5979.JPEG to image
# Uploaded n01558993_6013.JPEG to image
# Uploaded n01558993_6018.JPEG to image
# Uploaded n01558993_6059.JPEG to image
# Uploaded n01558993_608.JPEG to image
# Uploaded n01558993_6100.JPEG to image
# Uploaded n01558993_6135.JPEG to image
# Uploaded n01558993_6183.JPEG to image
# Uploaded n01558993_6186.JPEG to image
# Uploaded n01558993_6194.JPEG to image
# Uploaded n01558993_6223.JPEG to image
# Uploaded n01558993_6262.JPEG to image
# Uploaded n01558993_6394.JPEG to image
# Uploaded n01558993_6421.JPEG to image
# Uploaded n01558993_6447.JPEG to image
# Uploaded n01558993_6501.JPEG to image
# Uploaded n01558993_6521.JPEG to image
# Uploaded n01558993_6575.JPEG to image
# Uploaded n01558993_6702.JPEG to image
# Uploaded n01558993_6717.JPEG to image
# Uploaded n01558993_6724.JPEG to image
# Uploaded n01558993_6772.JPEG to image
# Uploaded n01558993_6786.JPEG to image
# Uploaded n01558993_6803.JPEG to image
# Uploaded n01558993_6833.JPEG to image
# Uploaded n01558993_6836.JPEG to image
# Uploaded n01558993_6837.JPEG to image
# Uploaded n01558993_6870.JPEG to image
# Uploaded n01558993_69.JPEG to image
# Uploaded n01558993_6907.JPEG to image
# Uploaded n01558993_6953.JPEG to image
# Uploaded n01558993_7.JPEG to image
# Uploaded n01558993_7015.JPEG to image
# Uploaded n01558993_7019.JPEG to image
# Uploaded n01558993_7025.JPEG to image
# Uploaded n01558993_7032.JPEG to image
# Uploaded n01558993_7057.JPEG to image
# Uploaded n01558993_7074.JPEG to image
# Uploaded n01558993_7079.JPEG to image
# Uploaded n01558993_7084.JPEG to image
# Uploaded n01558993_7088.JPEG to image
# Uploaded n01558993_709.JPEG to image
# Uploaded n01558993_7091.JPEG to image
# Uploaded n01558993_7116.JPEG to image
# Uploaded n01558993_7125.JPEG to image
# Uploaded n01558993_7131.JPEG to image
# Uploaded n01558993_7180.JPEG to image
# Uploaded n01558993_7187.JPEG to image
# Uploaded n01558993_7211.JPEG to image
# Uploaded n01558993_7234.JPEG to image
# Uploaded n01558993_724.JPEG to image
# Uploaded n01558993_7278.JPEG to image
# Uploaded n01558993_7302.JPEG to image
# Uploaded n01558993_7332.JPEG to image
# Uploaded n01558993_7336.JPEG to image
# Uploaded n01558993_7366.JPEG to image
# Uploaded n01558993_7367.JPEG to image
# Uploaded n01558993_748.JPEG to image
# Uploaded n01558993_7499.JPEG to image
# Uploaded n01558993_7548.JPEG to image
# Uploaded n01558993_7556.JPEG to image
# Uploaded n01558993_7567.JPEG to image
# Uploaded n01558993_7592.JPEG to image
# Uploaded n01558993_7634.JPEG to image
# Uploaded n01558993_7646.JPEG to image
# Uploaded n01558993_7654.JPEG to image
# Uploaded n01558993_776.JPEG to image
# Uploaded n01558993_7763.JPEG to image
# Uploaded n01558993_777.JPEG to image
# Uploaded n01558993_7800.JPEG to image
# Uploaded n01558993_7804.JPEG to image
# Uploaded n01558993_7824.JPEG to image
# Uploaded n01558993_7842.JPEG to image
# Uploaded n01558993_7844.JPEG to image
# Uploaded n01558993_7872.JPEG to image
# Uploaded n01558993_790.JPEG to image
# Uploaded n01558993_7900.JPEG to image
# Uploaded n01558993_792.JPEG to image
# Uploaded n01558993_7923.JPEG to image
# Uploaded n01558993_7951.JPEG to image
# Uploaded n01558993_7981.JPEG to image
# Uploaded n01558993_811.JPEG to image
# Uploaded n01558993_8140.JPEG to image
# Uploaded n01558993_8157.JPEG to image
# Uploaded n01558993_8177.JPEG to image
# Uploaded n01558993_8179.JPEG to image
# Uploaded n01558993_8197.JPEG to image
# Uploaded n01558993_8262.JPEG to image
# Uploaded n01558993_8271.JPEG to image
# Uploaded n01558993_8275.JPEG to image
# Uploaded n01558993_828.JPEG to image
# Uploaded n01558993_8430.JPEG to image
# Uploaded n01558993_8475.JPEG to image
# Uploaded n01558993_8478.JPEG to image
# Uploaded n01558993_8560.JPEG to image
# Uploaded n01558993_8600.JPEG to image
# Uploaded n01558993_8618.JPEG to image
# Uploaded n01558993_8693.JPEG to image
# Uploaded n01558993_8723.JPEG to image
# Uploaded n01558993_8777.JPEG to image
# Uploaded n01558993_8813.JPEG to image
# Uploaded n01558993_8816.JPEG to image
# Uploaded n01558993_8903.JPEG to image
# Uploaded n01558993_8994.JPEG to image
# Uploaded n01558993_907.JPEG to image
# Uploaded n01558993_9120.JPEG to image
# Uploaded n01558993_9137.JPEG to image
# Uploaded n01558993_9141.JPEG to image
# Uploaded n01558993_9149.JPEG to image
# Uploaded n01558993_9218.JPEG to image
# Uploaded n01558993_927.JPEG to image
# Uploaded n01558993_9314.JPEG to image
# Uploaded n01558993_9347.JPEG to image
# Uploaded n01558993_9441.JPEG to image
# Uploaded n01558993_9492.JPEG to image
# Uploaded n01558993_9561.JPEG to image
# Uploaded n01558993_9635.JPEG to image
# Uploaded n01558993_9649.JPEG to image
# Uploaded n01558993_968.JPEG to image
# Uploaded n01558993_9684.JPEG to image
# Uploaded n01558993_9711.JPEG to image
# Uploaded n01558993_9715.JPEG to image
# Uploaded n01558993_9850.JPEG to image
# Uploaded n01558993_9866.JPEG to image
# Uploaded n01558993_9870.JPEG to image
# Uploaded n01558993_9927.JPEG to image
# Uploaded n01558993_9933.JPEG to image
# Uploaded n01558993_9957.JPEG to image
# Uploaded n01558993_9967.JPEG to image
# Uploaded n01558993_9992.JPEG to image
# ./miniImageNet\n01704323
# Uploaded n01704323_10005.JPEG to image
# Uploaded n01704323_10031.JPEG to image
# Uploaded n01704323_10062.JPEG to image
# Uploaded n01704323_10097.JPEG to image
# Uploaded n01704323_1011.JPEG to image
# Uploaded n01704323_1012.JPEG to image
# Uploaded n01704323_10165.JPEG to image
# Uploaded n01704323_10178.JPEG to image
# Uploaded n01704323_1021.JPEG to image
# Uploaded n01704323_10234.JPEG to image
# Uploaded n01704323_10237.JPEG to image
# Uploaded n01704323_10239.JPEG to image
# Uploaded n01704323_10249.JPEG to image
# Uploaded n01704323_10302.JPEG to image
# Uploaded n01704323_10316.JPEG to image
# Uploaded n01704323_10375.JPEG to image
# Uploaded n01704323_10469.JPEG to image
# Uploaded n01704323_10505.JPEG to image
# Uploaded n01704323_1058.JPEG to image
# Uploaded n01704323_10668.JPEG to image
# Uploaded n01704323_1070.JPEG to image
# Uploaded n01704323_1072.JPEG to image
# Uploaded n01704323_10810.JPEG to image
# Uploaded n01704323_10845.JPEG to image
# Uploaded n01704323_10902.JPEG to image
# Uploaded n01704323_10921.JPEG to image
# Uploaded n01704323_1098.JPEG to image
# Uploaded n01704323_10998.JPEG to image
# Uploaded n01704323_11304.JPEG to image
# Uploaded n01704323_1147.JPEG to image
# Uploaded n01704323_1152.JPEG to image
# Uploaded n01704323_11623.JPEG to image
# Uploaded n01704323_11645.JPEG to image
# Uploaded n01704323_1171.JPEG to image
# Uploaded n01704323_1179.JPEG to image
# Uploaded n01704323_1182.JPEG to image
# Uploaded n01704323_1190.JPEG to image
# Uploaded n01704323_11971.JPEG to image
# Uploaded n01704323_1198.JPEG to image
# Uploaded n01704323_120.JPEG to image
# Uploaded n01704323_1214.JPEG to image
# Uploaded n01704323_1223.JPEG to image
# Uploaded n01704323_1231.JPEG to image
# Uploaded n01704323_1232.JPEG to image
# Uploaded n01704323_1249.JPEG to image
# Uploaded n01704323_1255.JPEG to image
# Uploaded n01704323_1260.JPEG to image
# Uploaded n01704323_1263.JPEG to image
# Uploaded n01704323_12776.JPEG to image
# Uploaded n01704323_1280.JPEG to image
# Uploaded n01704323_12836.JPEG to image
# Uploaded n01704323_1285.JPEG to image
# ...
# Uploaded n02174001_1253.JPEG to image
# Uploaded n02174001_128.JPEG to image
# Uploaded n02174001_129.JPEG to image
# Uploaded n02174001_1292.JPEG to image
# Uploaded n02174001_130.JPEG to image
# Uploaded n02174001_1301.JPEG to image
# Uploaded n02174001_1311.JPEG to image
# Uploaded n02174001_1316.JPEG to image
# Uploaded n02174001_134.JPEG to image
# Uploaded n02174001_1346.JPEG to image
# Uploaded n02174001_1353.JPEG to image
# Uploaded n02174001_1390.JPEG to image
# Uploaded n02174001_140.JPEG to image
# Uploaded n02174001_1403.JPEG to image
# Uploaded n02174001_142.JPEG to image
# Uploaded n02174001_1421.JPEG to image
# Uploaded n02174001_1485.JPEG to image
# Uploaded n02174001_1490.JPEG to image
# Uploaded n02174001_1501.JPEG to image
# Uploaded n02174001_1517.JPEG to image
# Uploaded n02174001_1535.JPEG to image
# Uploaded n02174001_154.JPEG to image
# Uploaded n02174001_1553.JPEG to image
# Uploaded n02174001_1557.JPEG to image
# Uploaded n02174001_1564.JPEG to image
# Uploaded n02174001_1570.JPEG to image
# Uploaded n02174001_1586.JPEG to image
# Uploaded n02174001_159.JPEG to image
# Uploaded n02174001_1590.JPEG to image
# Uploaded n02174001_1592.JPEG to image
# Uploaded n02174001_1595.JPEG to image
# Uploaded n02174001_162.JPEG to image
# Uploaded n02174001_1632.JPEG to image
# Uploaded n02174001_1633.JPEG to image
# Uploaded n02174001_1656.JPEG to image
# Uploaded n02174001_1661.JPEG to image
# Uploaded n02174001_1669.JPEG to image
# Uploaded n02174001_167.JPEG to image
# Uploaded n02174001_1683.JPEG to image
# Uploaded n02174001_1693.JPEG to image
# Uploaded n02174001_1698.JPEG to image
# Uploaded n02174001_1699.JPEG to image
# Uploaded n02174001_1708.JPEG to image
# Uploaded n02174001_171.JPEG to image
# Uploaded n02174001_1714.JPEG to image
# Uploaded n02174001_1729.JPEG to image
# Uploaded n02174001_1730.JPEG to image
# Uploaded n02174001_1740.JPEG to image
# Uploaded n02174001_176.JPEG to image
# Uploaded n02174001_1778.JPEG to image
# Uploaded n02174001_1780.JPEG to image
# Uploaded n02174001_1781.JPEG to image
# Uploaded n02174001_1782.JPEG to image
# Uploaded n02174001_1786.JPEG to image
# Uploaded n02174001_179.JPEG to image
# Uploaded n02174001_1794.JPEG to image
# Uploaded n02174001_182.JPEG to image
# Uploaded n02174001_1825.JPEG to image
# Uploaded n02174001_1828.JPEG to image
# Uploaded n02174001_1841.JPEG to image
# Uploaded n02174001_1848.JPEG to image
# Uploaded n02174001_1857.JPEG to image
# Uploaded n02174001_188.JPEG to image
# Uploaded n02174001_1893.JPEG to image
# Uploaded n02174001_1900.JPEG to image
# Uploaded n02174001_1920.JPEG to image
# Uploaded n02174001_1939.JPEG to image
# Uploaded n02174001_1944.JPEG to image
# Uploaded n02174001_1954.JPEG to image
# Uploaded n02174001_1967.JPEG to image
# Uploaded n02174001_1976.JPEG to image
# Uploaded n02174001_2003.JPEG to image
# Uploaded n02174001_2027.JPEG to image
# Uploaded n02174001_203.JPEG to image
# Uploaded n02174001_2034.JPEG to image
# Uploaded n02174001_204.JPEG to image
# Uploaded n02174001_2048.JPEG to image
# Uploaded n02174001_2056.JPEG to image
# Uploaded n02174001_206.JPEG to image
# Uploaded n02174001_2065.JPEG to image
# Uploaded n02174001_2067.JPEG to image
# Uploaded n02174001_2068.JPEG to image
# Uploaded n02174001_2084.JPEG to image
# Uploaded n02174001_211.JPEG to image
# Uploaded n02174001_2110.JPEG to image
# Uploaded n02174001_2116.JPEG to image
# Uploaded n02174001_2130.JPEG to image
# Uploaded n02174001_2142.JPEG to image
# Uploaded n02174001_2145.JPEG to image
# Uploaded n02174001_2152.JPEG to image
# Uploaded n02174001_2176.JPEG to image
# Uploaded n02174001_2197.JPEG to image
# Uploaded n02174001_2198.JPEG to image
# Uploaded n02174001_2199.JPEG to image
# Uploaded n02174001_2207.JPEG to image
# Uploaded n02174001_2231.JPEG to image
# Uploaded n02174001_2240.JPEG to image
# Uploaded n02174001_225.JPEG to image
# Uploaded n02174001_2266.JPEG to image
# Uploaded n02174001_2274.JPEG to image
# Uploaded n02174001_2294.JPEG to image
# Uploaded n02174001_232.JPEG to image
# Uploaded n02174001_2321.JPEG to image
# Uploaded n02174001_2327.JPEG to image
# Uploaded n02174001_2329.JPEG to image
# Uploaded n02174001_2330.JPEG to image
# Uploaded n02174001_2340.JPEG to image
# Uploaded n02174001_2346.JPEG to image
# Uploaded n02174001_2373.JPEG to image
# Uploaded n02174001_2406.JPEG to image
# Uploaded n02174001_243.JPEG to image
# Uploaded n02174001_2433.JPEG to image
# Uploaded n02174001_2438.JPEG to image
# Uploaded n02174001_2475.JPEG to image
# Uploaded n02174001_2476.JPEG to image
# Uploaded n02174001_249.JPEG to image
# Uploaded n02174001_25.JPEG to image
# Uploaded n02174001_2505.JPEG to image
# Uploaded n02174001_2506.JPEG to image
# Uploaded n02174001_2512.JPEG to image
# Uploaded n02174001_252.JPEG to image
# Uploaded n02174001_2527.JPEG to image
# Uploaded n02174001_2532.JPEG to image
# Uploaded n02174001_2555.JPEG to image
# Uploaded n02174001_2566.JPEG to image
# Uploaded n02174001_2577.JPEG to image
# Uploaded n02174001_2585.JPEG to image
# Uploaded n02174001_2602.JPEG to image
# Uploaded n02174001_2625.JPEG to image
# Uploaded n02174001_2633.JPEG to image
# Uploaded n02174001_2637.JPEG to image
# Uploaded n02174001_2644.JPEG to image
# Uploaded n02174001_2657.JPEG to image
# Uploaded n02174001_2660.JPEG to image
# Uploaded n02174001_2672.JPEG to image
# Uploaded n02174001_2699.JPEG to image
# Uploaded n02174001_2710.JPEG to image
# Uploaded n02174001_2711.JPEG to image
# Uploaded n02174001_272.JPEG to image
# Uploaded n02174001_2724.JPEG to image
# Uploaded n02174001_2725.JPEG to image
# Uploaded n02174001_2733.JPEG to image
# Uploaded n02174001_2736.JPEG to image
# Uploaded n02174001_276.JPEG to image
# Uploaded n02174001_2767.JPEG to image
# Uploaded n02174001_2772.JPEG to image
# Uploaded n02174001_2785.JPEG to image
# Uploaded n02174001_2796.JPEG to image
# Uploaded n02174001_28.JPEG to image
# Uploaded n02174001_2810.JPEG to image
# Uploaded n02174001_2811.JPEG to image
# Uploaded n02174001_282.JPEG to image
# Uploaded n02174001_2825.JPEG to image
# Uploaded n02174001_2837.JPEG to image
# Uploaded n02174001_2840.JPEG to image
# Uploaded n02174001_2846.JPEG to image
# Uploaded n02174001_2851.JPEG to image
# Uploaded n02174001_2855.JPEG to image
# Uploaded n02174001_2861.JPEG to image
# Uploaded n02174001_2896.JPEG to image
# Uploaded n02174001_2897.JPEG to image
# Uploaded n02174001_2898.JPEG to image
# Uploaded n02174001_2900.JPEG to image
# Uploaded n02174001_2913.JPEG to image
# Uploaded n02174001_2920.JPEG to image
# Uploaded n02174001_2940.JPEG to image
# Uploaded n02174001_2941.JPEG to image
# Uploaded n02174001_295.JPEG to image
# Uploaded n02174001_2956.JPEG to image
# Uploaded n02174001_2957.JPEG to image
# Uploaded n02174001_2967.JPEG to image
# Uploaded n02174001_2983.JPEG to image
# Uploaded n02174001_2997.JPEG to image
# Uploaded n02174001_3007.JPEG to image
# Uploaded n02174001_3018.JPEG to image
# Uploaded n02174001_3028.JPEG to image
# Uploaded n02174001_3045.JPEG to image
# Uploaded n02174001_3077.JPEG to image
# Uploaded n02174001_3126.JPEG to image
# Uploaded n02174001_3146.JPEG to image
# Uploaded n02174001_3166.JPEG to image
# Uploaded n02174001_3173.JPEG to image
# Uploaded n02174001_3177.JPEG to image
# Uploaded n02174001_3201.JPEG to image
# Uploaded n02174001_3208.JPEG to image
# Uploaded n02174001_321.JPEG to image
# Uploaded n02174001_3212.JPEG to image
# Uploaded n02174001_3222.JPEG to image
# Uploaded n02174001_3223.JPEG to image
# Uploaded n02174001_3244.JPEG to image
# Uploaded n02174001_3256.JPEG to image
# Uploaded n02174001_330.JPEG to image
# Uploaded n02174001_3319.JPEG to image
# Uploaded n02174001_3349.JPEG to image
# Uploaded n02174001_3352.JPEG to image
# Uploaded n02174001_3354.JPEG to image
# Uploaded n02174001_3360.JPEG to image
# Uploaded n02174001_3368.JPEG to image
# Uploaded n02174001_3388.JPEG to image
# Uploaded n02174001_34.JPEG to image
# Uploaded n02174001_3403.JPEG to image
# Uploaded n02174001_3411.JPEG to image
# Uploaded n02174001_3427.JPEG to image
# Uploaded n02174001_3453.JPEG to image
# Uploaded n02174001_3473.JPEG to image
# Uploaded n02174001_3475.JPEG to image
# Uploaded n02174001_3499.JPEG to image
# Uploaded n02174001_353.JPEG to image
# Uploaded n02174001_3534.JPEG to image
# Uploaded n02174001_354.JPEG to image
# Uploaded n02174001_3570.JPEG to image
# Uploaded n02174001_3589.JPEG to image
# Uploaded n02174001_3609.JPEG to image
# Uploaded n02174001_362.JPEG to image
# Uploaded n02174001_3630.JPEG to image
# Uploaded n02174001_3660.JPEG to image
# Uploaded n02174001_3675.JPEG to image
# Uploaded n02174001_3696.JPEG to image
# Uploaded n02174001_370.JPEG to image
# Uploaded n02174001_3847.JPEG to image
# Uploaded n02174001_3892.JPEG to image
# Uploaded n02174001_3897.JPEG to image
# Uploaded n02174001_3899.JPEG to image
# Uploaded n02174001_3908.JPEG to image
# Uploaded n02174001_391.JPEG to image
# Uploaded n02174001_3914.JPEG to image
# Uploaded n02174001_3929.JPEG to image
# Uploaded n02174001_3944.JPEG to image
# Uploaded n02174001_3958.JPEG to image
# Uploaded n02174001_3966.JPEG to image
# Uploaded n02174001_3969.JPEG to image
# Uploaded n02174001_3973.JPEG to image
# Uploaded n02174001_3983.JPEG to image
# Uploaded n02174001_4.JPEG to image
# Uploaded n02174001_4022.JPEG to image
# Uploaded n02174001_4027.JPEG to image
# Uploaded n02174001_4068.JPEG to image
# Uploaded n02174001_4094.JPEG to image
# Uploaded n02174001_4095.JPEG to image
# Uploaded n02174001_4103.JPEG to image
# Uploaded n02174001_4107.JPEG to image
# Uploaded n02174001_4135.JPEG to image
# Uploaded n02174001_4151.JPEG to image
# Uploaded n02174001_4181.JPEG to image
# Uploaded n02174001_4255.JPEG to image
# Uploaded n02174001_4268.JPEG to image
# Uploaded n02174001_427.JPEG to image
# Uploaded n02174001_4271.JPEG to image
# Uploaded n02174001_4289.JPEG to image
# Uploaded n02174001_4331.JPEG to image
# Uploaded n02174001_4377.JPEG to image
# Uploaded n02174001_4383.JPEG to image
# Uploaded n02174001_4388.JPEG to image
# Uploaded n02174001_4392.JPEG to image
# Uploaded n02174001_4395.JPEG to image
# Uploaded n02174001_4398.JPEG to image
# Uploaded n02174001_4399.JPEG to image
# Uploaded n02174001_4420.JPEG to image
# Uploaded n02174001_4428.JPEG to image
# Uploaded n02174001_443.JPEG to image
# Uploaded n02174001_4458.JPEG to image
# Uploaded n02174001_4472.JPEG to image
# Uploaded n02174001_4489.JPEG to image
# Uploaded n02174001_449.JPEG to image
# Uploaded n02174001_4492.JPEG to image
# Uploaded n02174001_4493.JPEG to image
# Uploaded n02174001_4496.JPEG to image
# Uploaded n02174001_4499.JPEG to image
# Uploaded n02174001_450.JPEG to image
# Uploaded n02174001_4525.JPEG to image
# Uploaded n02174001_4537.JPEG to image
# Uploaded n02174001_4555.JPEG to image
# Uploaded n02174001_4559.JPEG to image
# Uploaded n02174001_4572.JPEG to image
# Uploaded n02174001_4584.JPEG to image
# Uploaded n02174001_4588.JPEG to image
# Uploaded n02174001_460.JPEG to image
# Uploaded n02174001_4602.JPEG to image
# Uploaded n02174001_4605.JPEG to image
# Uploaded n02174001_4608.JPEG to image
# Uploaded n02174001_461.JPEG to image
# Uploaded n02174001_4612.JPEG to image
# Uploaded n02174001_4619.JPEG to image
# Uploaded n02174001_4623.JPEG to image
# Uploaded n02174001_4627.JPEG to image
# Uploaded n02174001_4633.JPEG to image
# Uploaded n02174001_4656.JPEG to image
# Uploaded n02174001_4662.JPEG to image
# Uploaded n02174001_4666.JPEG to image
# Uploaded n02174001_4680.JPEG to image
# Uploaded n02174001_4704.JPEG to image
# Uploaded n02174001_4727.JPEG to image
# Uploaded n02174001_4728.JPEG to image
# Uploaded n02174001_4735.JPEG to image
# Uploaded n02174001_4744.JPEG to image
# Uploaded n02174001_4762.JPEG to image
# Uploaded n02174001_4793.JPEG to image
# Uploaded n02174001_4795.JPEG to image
# Uploaded n02174001_4808.JPEG to image
# Uploaded n02174001_4854.JPEG to image
# Uploaded n02174001_4862.JPEG to image
# Uploaded n02174001_4865.JPEG to image
# Uploaded n02174001_4872.JPEG to image
# Uploaded n02174001_4886.JPEG to image
# Uploaded n02174001_4895.JPEG to image
# Uploaded n02174001_4903.JPEG to image
# Uploaded n02174001_4930.JPEG to image
# Uploaded n02174001_4931.JPEG to image
# Uploaded n02174001_4961.JPEG to image
# Uploaded n02174001_4963.JPEG to image
# Uploaded n02174001_4966.JPEG to image
# Uploaded n02174001_4969.JPEG to image
# Uploaded n02174001_4982.JPEG to image
# Uploaded n02174001_4992.JPEG to image
# Uploaded n02174001_5001.JPEG to image
# Uploaded n02174001_5006.JPEG to image
# Uploaded n02174001_5014.JPEG to image
# Uploaded n02174001_5019.JPEG to image
# Uploaded n02174001_502.JPEG to image
# Uploaded n02174001_5026.JPEG to image
# Uploaded n02174001_5031.JPEG to image
# Uploaded n02174001_5039.JPEG to image
# Uploaded n02174001_5040.JPEG to image
# Uploaded n02174001_5044.JPEG to image
# Uploaded n02174001_5056.JPEG to image
# Uploaded n02174001_5058.JPEG to image
# Uploaded n02174001_5062.JPEG to image
# Uploaded n02174001_5086.JPEG to image
# Uploaded n02174001_5087.JPEG to image
# Uploaded n02174001_5091.JPEG to image
# Uploaded n02174001_5093.JPEG to image
# Uploaded n02174001_5121.JPEG to image
# Uploaded n02174001_5125.JPEG to image
# Uploaded n02174001_5137.JPEG to image
# Uploaded n02174001_5142.JPEG to image
# Uploaded n02174001_5148.JPEG to image
# Uploaded n02174001_5152.JPEG to image
# Uploaded n02174001_5158.JPEG to image
# Uploaded n02174001_516.JPEG to image
# Uploaded n02174001_5162.JPEG to image
# Uploaded n02174001_5172.JPEG to image
# Uploaded n02174001_5186.JPEG to image
# Uploaded n02174001_5217.JPEG to image
# Uploaded n02174001_5220.JPEG to image
# Uploaded n02174001_5228.JPEG to image
# Uploaded n02174001_5230.JPEG to image
# Uploaded n02174001_5237.JPEG to image
# Uploaded n02174001_5239.JPEG to image
# Uploaded n02174001_5261.JPEG to image
# Uploaded n02174001_527.JPEG to image
# Uploaded n02174001_5278.JPEG to image
# Uploaded n02174001_5288.JPEG to image
# Uploaded n02174001_5294.JPEG to image
# Uploaded n02174001_53.JPEG to image
# Uploaded n02174001_530.JPEG to image
# Uploaded n02174001_5301.JPEG to image
# Uploaded n02174001_5302.JPEG to image
# Uploaded n02174001_5305.JPEG to image
# Uploaded n02174001_5313.JPEG to image
# Uploaded n02174001_5327.JPEG to image
# Uploaded n02174001_533.JPEG to image
# Uploaded n02174001_5336.JPEG to image
# Uploaded n02174001_534.JPEG to image
# Uploaded n02174001_5343.JPEG to image
# Uploaded n02174001_5374.JPEG to image
# Uploaded n02174001_5423.JPEG to image
# Uploaded n02174001_5427.JPEG to image
# Uploaded n02174001_5460.JPEG to image
# Uploaded n02174001_5463.JPEG to image
# Uploaded n02174001_5497.JPEG to image
# Uploaded n02174001_5507.JPEG to image
# Uploaded n02174001_5508.JPEG to image
# Uploaded n02174001_5516.JPEG to image
# Uploaded n02174001_5519.JPEG to image
# Uploaded n02174001_5527.JPEG to image
# Uploaded n02174001_554.JPEG to image
# Uploaded n02174001_5546.JPEG to image
# Uploaded n02174001_5547.JPEG to image
# Uploaded n02174001_5549.JPEG to image
# Uploaded n02174001_5553.JPEG to image
# Uploaded n02174001_5562.JPEG to image
# Uploaded n02174001_5585.JPEG to image
# Uploaded n02174001_5606.JPEG to image
# Uploaded n02174001_5619.JPEG to image
# Uploaded n02174001_5628.JPEG to image
# Uploaded n02174001_5647.JPEG to image
# Uploaded n02174001_5649.JPEG to image
# Uploaded n02174001_5651.JPEG to image
# Uploaded n02174001_5653.JPEG to image
# Uploaded n02174001_566.JPEG to image
# Uploaded n02174001_5671.JPEG to image
# Uploaded n02174001_5692.JPEG to image
# Uploaded n02174001_570.JPEG to image
# Uploaded n02174001_5704.JPEG to image
# Uploaded n02174001_5719.JPEG to image
# Uploaded n02174001_5720.JPEG to image
# Uploaded n02174001_573.JPEG to image
# Uploaded n02174001_5746.JPEG to image
# Uploaded n02174001_5760.JPEG to image
# Uploaded n02174001_5775.JPEG to image
# Uploaded n02174001_5778.JPEG to image
# Uploaded n02174001_5781.JPEG to image
# Uploaded n02174001_5788.JPEG to image
# Uploaded n02174001_5792.JPEG to image
# Uploaded n02174001_5812.JPEG to image
# Uploaded n02174001_5816.JPEG to image
# Uploaded n02174001_5830.JPEG to image
# Uploaded n02174001_5847.JPEG to image
# Uploaded n02174001_5852.JPEG to image
# Uploaded n02174001_5901.JPEG to image
# Uploaded n02174001_5905.JPEG to image
# Uploaded n02174001_5956.JPEG to image
# Uploaded n02174001_5973.JPEG to image
# Uploaded n02174001_599.JPEG to image
# Uploaded n02174001_6055.JPEG to image
# Uploaded n02174001_6069.JPEG to image
# Uploaded n02174001_608.JPEG to image
# Uploaded n02174001_6119.JPEG to image
# Uploaded n02174001_6145.JPEG to image
# Uploaded n02174001_615.JPEG to image
# Uploaded n02174001_6222.JPEG to image
# Uploaded n02174001_6299.JPEG to image

# %%
import io
from minio import Minio

def read_image_from_minio(bucket_name, object_name):
    try:
        # Get the object from MinIO
        response = client.get_object(bucket_name, object_name)

        # Create an in-memory buffer and read the content into it
        image_data = io.BytesIO()
        for data in response.stream(32*1024):  # Read in chunks of 32KB
            image_data.write(data)

        # Reset pointer to the start of the buffer
        image_data.seek(0)

        # Optionally, you can open the image in memory using PIL (if needed)
        # from PIL import Image
        image = Image.open(image_data)

        # # You can now work with the image in memory, e.g., display it
        # image.show()  # Display the image

        return image  # Or return image_data if you need the raw bytes
    except Exception as e:
        print(f"Error reading image {object_name}: {e}")

# %%
object_name = "n02088094_1045.JPEG"  # The file path in MinIO

read_image_from_minio(bucket_name, object_name)
# Out:
# Error reading image n02088094_1045.JPEG: S3 operation failed; code: NoSuchKey, message: The specified key does not exist., resource: /image/n02088094_1045.JPEG, request_id: 180D6359A2BBD715, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8, bucket_name: image, object_name: n02088094_1045.JPEG

# %%
from qdrant_client import models, QdrantClient
from qdrant_client.models import PointStruct
from utils import FeatureExtractor
from PIL import Image
import os
import uuid  # To generate unique IDs for each point
qdrant_client = QdrantClient(url="http://localhost:6333")
collection_name = "img_embed"
feature_extractor = FeatureExtractor()
def populate_data():
        # Check if collection exists, if not create it
        try:
            qdrant_client.get_collection(collection_name)
        except Exception:
            qdrant_client.create_collection(
                collection_name=collection_name,
                vectors_config=models.VectorParams(
                    size=768,  # Adjust size based on your vector dimension
                    distance=models.Distance.DOT,  # Dot product distance
                ),
            )
        # Root directory for images
        root = "./miniImageNet"

        insert = True
        if insert:
            # Walk through the directory and process each image
            for dirpath, foldername, filenames in os.walk(root):
                for filename in filenames:
                    if filename.endswith(".JPEG"):
                        filepath = os.path.join(dirpath, filename)
                        image = Image.open(filepath).convert("RGB") 
                        # Extract the image embedding
                        image_embedding = feature_extractor(image)

                        # Create a unique ID for each point
                        point_id = str(uuid.uuid4())

                        # Create the payload as a dictionary (you can add more metadata here)
                        payload = {"filepath": filepath}
                        # print(payload, image_embedding.shape)
                        # Upload the point to the Qdrant collection
                        qdrant_client.upload_points(
                            # Ensure this matches your collection name
                            collection_name=collection_name,
                            points=[models.PointStruct(
                                id=point_id,  # Unique ID
                                vector=image_embedding.tolist(),  # Ensure this is a list
                                payload=payload  # Payload should be a dictionary
                            )],
                        )
                        # print(response)
        return
populate_data()
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\Admin\anaconda3\Lib\site-packages\transformers\models\vit\feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
